# %%
import sys
import os

# Add the scripts directory to the system path
sys.path.append(r"D:\Kifya_training\Week 1\Financial-News-Sentiment-Analysis\scripts")
import pandas as pd
import talib
from data_loader import load_data
from visualization import (
    plot_distribution, 
    plot_bar, 
    plot_word_cloud,
    plot_sentiment_distribution,
    plot_sentiment_categories,
    plot_daily_publication,
    plot_hourly_publication,
    plot_heatmap
)

# %%
# Define the base directory for the stock data
base_dir = r"D:\Kifya_training\Week 1\Technical  Content\Data\yfinance_data"

# Define file paths for each stock with correct filenames
file_names = [
    "AAPL_historical_data.csv",
    "AMZN_historical_data.csv",
    "GOOG_historical_data.csv",
    "META_historical_data.csv",
    "MSFT_historical_data.csv",
    "NVDA_historical_data.csv",
    "TSLA_historical_data.csv"
]

# Loop through each file name, construct the full file path, check if it exists, and load the data
for file_name in file_names:
    file_path = os.path.join(base_dir, file_name)
    print(f"Checking file path: {file_path}")
    if os.path.exists(file_path):
        df = load_data(file_path)
        print(f"\nFirst few rows of data from {file_name}:")
        print(df.head())
    else:
        print(f"Error: The file at {file_path} does not exist.")

# Display the first few rows of the dataset
df.head()
# Out:
# Checking file path: D:\Kifya_training\Week 1\Technical  Content\Data\yfinance_data\AAPL_historical_data.csv
# Dataset Loaded and Preprocessed Successfully!
# Columns in Dataset: Index(['date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Dividends', 'Stock Splits', 'date_only', 'hour', 'day_of_week'],
#       dtype='object')
# Data Types:
# date            datetime64[ns]
# Open                   float64
# High                   float64
# Low                    float64
# Close                  float64
# Adj Close              float64
# Volume                   int64
# Dividends              float64
# Stock Splits           float64
# date_only               object
# hour                     int32
# day_of_week             object
# dtype: object
#
# First few rows of data from AAPL_historical_data.csv:
#         date      Open      High       Low     Close  Adj Close     Volume  \
# 0 1980-12-12  0.128348  0.128906  0.128348  0.128348   0.098943  469033600
# 1 1980-12-15  0.122210  0.122210  0.121652  0.121652   0.093781  175884800
# 2 1980-12-16  0.113281  0.113281  0.112723  0.112723   0.086898  105728000
# 3 1980-12-17  0.115513  0.116071  0.115513  0.115513   0.089049   86441600
# 4 1980-12-18  0.118862  0.119420  0.118862  0.118862   0.091630   73449600
#
#    Dividends  Stock Splits   date_only  hour day_of_week
# 0        0.0           0.0  1980-12-12     0      Friday
# 1        0.0           0.0  1980-12-15     0      Monday
# 2        0.0           0.0  1980-12-16     0     Tuesday
# 3        0.0           0.0  1980-12-17     0   Wednesday
# 4        0.0           0.0  1980-12-18     0    Thursday
# Checking file path: D:\Kifya_training\Week 1\Technical  Content\Data\yfinance_data\AMZN_historical_data.csv
# Dataset Loaded and Preprocessed Successfully!
# Columns in Dataset: Index(['date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Dividends', 'Stock Splits', 'date_only', 'hour', 'day_of_week'],
#       dtype='object')
# Data Types:
# date            datetime64[ns]
# Open                   float64
# High                   float64
# Low                    float64
# Close                  float64
# Adj Close              float64
# Volume                   int64
# Dividends              float64
# Stock Splits           float64
# date_only               object
# hour                     int32
# day_of_week             object
# dtype: object
#
# First few rows of data from AMZN_historical_data.csv:
#         date      Open      High       Low     Close  Adj Close      Volume  \
# 0 1997-05-15  0.121875  0.125000  0.096354  0.097917   0.097917  1443120000
# 1 1997-05-16  0.098438  0.098958  0.085417  0.086458   0.086458   294000000
# 2 1997-05-19  0.088021  0.088542  0.081250  0.085417   0.085417   122136000
# 3 1997-05-20  0.086458  0.087500  0.081771  0.081771   0.081771   109344000
# 4 1997-05-21  0.081771  0.082292  0.068750  0.071354   0.071354   377064000
#
#    Dividends  Stock Splits   date_only  hour day_of_week
# 0        0.0           0.0  1997-05-15     0    Thursday
# 1        0.0           0.0  1997-05-16     0      Friday
# 2        0.0           0.0  1997-05-19     0      Monday
# 3        0.0           0.0  1997-05-20     0     Tuesday
# 4        0.0           0.0  1997-05-21     0   Wednesday
# Checking file path: D:\Kifya_training\Week 1\Technical  Content\Data\yfinance_data\GOOG_historical_data.csv
# Dataset Loaded and Preprocessed Successfully!
# Columns in Dataset: Index(['date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Dividends', 'Stock Splits', 'date_only', 'hour', 'day_of_week'],
#       dtype='object')
# Data Types:
# date            datetime64[ns]
# Open                   float64
# High                   float64
# Low                    float64
# Close                  float64
# Adj Close              float64
# Volume                   int64
# Dividends              float64
# Stock Splits           float64
# date_only               object
# hour                     int32
# day_of_week             object
# dtype: object
#
# First few rows of data from GOOG_historical_data.csv:
#         date      Open      High       Low     Close  Adj Close     Volume  \
# 0 2004-08-19  2.490664  2.591785  2.390042  2.499133   2.496292  897427216
# 1 2004-08-20  2.515820  2.716817  2.503118  2.697639   2.694573  458857488
# 2 2004-08-23  2.758411  2.826406  2.716070  2.724787   2.721690  366857939
# 3 2004-08-24  2.770615  2.779581  2.579581  2.611960   2.608991  306396159
# 4 2004-08-25  2.614201  2.689918  2.587302  2.640104   2.637103  184645512
#
#    Dividends  Stock Splits   date_only  hour day_of_week
# 0        0.0           0.0  2004-08-19     0    Thursday
# 1        0.0           0.0  2004-08-20     0      Friday
# 2        0.0           0.0  2004-08-23     0      Monday
# 3        0.0           0.0  2004-08-24     0     Tuesday
# 4        0.0           0.0  2004-08-25     0   Wednesday
# Checking file path: D:\Kifya_training\Week 1\Technical  Content\Data\yfinance_data\META_historical_data.csv
# Dataset Loaded and Preprocessed Successfully!
# Columns in Dataset: Index(['date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Dividends', 'Stock Splits', 'date_only', 'hour', 'day_of_week'],
#       dtype='object')
# Data Types:
# date            datetime64[ns]
# Open                   float64
# High                   float64
# Low                    float64
# Close                  float64
# Adj Close              float64
# Volume                   int64
# Dividends              float64
# Stock Splits           float64
# date_only               object
# hour                     int32
# day_of_week             object
# dtype: object
#
# First few rows of data from META_historical_data.csv:
#         date       Open       High        Low      Close  Adj Close    Volume  \
# 0 2012-12-12  28.000000  28.139999  27.370001  27.580000  27.523441  46704200
# 1 2012-12-13  27.590000  28.750000  27.430000  28.240000  28.182087  81051600
# 2 2012-12-14  28.180000  28.330000  26.760000  26.809999  26.755020  91631600
# 3 2012-12-17  26.770000  27.000000  26.320000  26.750000  26.695143  57742500
# 4 2012-12-18  26.959999  27.910000  26.900000  27.709999  27.653173  60512900
#
#    Dividends  Stock Splits   date_only  hour day_of_week
# 0        0.0           0.0  2012-12-12     0   Wednesday
# 1        0.0           0.0  2012-12-13     0    Thursday
# 2        0.0           0.0  2012-12-14     0      Friday
# 3        0.0           0.0  2012-12-17     0      Monday
# 4        0.0           0.0  2012-12-18     0     Tuesday
# Checking file path: D:\Kifya_training\Week 1\Technical  Content\Data\yfinance_data\MSFT_historical_data.csv
# Dataset Loaded and Preprocessed Successfully!
# Columns in Dataset: Index(['date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Dividends', 'Stock Splits', 'date_only', 'hour', 'day_of_week'],
#       dtype='object')
# Data Types:
# date            datetime64[ns]
# Open                   float64
# High                   float64
# Low                    float64
# Close                  float64
# Adj Close              float64
# Volume                   int64
# Dividends              float64
# Stock Splits           float64
# date_only               object
# hour                     int32
# day_of_week             object
# dtype: object
#
# First few rows of data from MSFT_historical_data.csv:
#         date      Open      High       Low     Close  Adj Close      Volume  \
# 0 1986-03-13  0.088542  0.101563  0.088542  0.097222   0.059946  1031788800
# 1 1986-03-14  0.097222  0.102431  0.097222  0.100694   0.062087   308160000
# 2 1986-03-17  0.100694  0.103299  0.100694  0.102431   0.063158   133171200
# 3 1986-03-18  0.102431  0.103299  0.098958  0.099826   0.061552    67766400
# 4 1986-03-19  0.099826  0.100694  0.097222  0.098090   0.060482    47894400
#
#    Dividends  Stock Splits   date_only  hour day_of_week
# 0        0.0           0.0  1986-03-13     0    Thursday
# 1        0.0           0.0  1986-03-14     0      Friday
# 2        0.0           0.0  1986-03-17     0      Monday
# 3        0.0           0.0  1986-03-18     0     Tuesday
# 4        0.0           0.0  1986-03-19     0   Wednesday
# Checking file path: D:\Kifya_training\Week 1\Technical  Content\Data\yfinance_data\NVDA_historical_data.csv
# Dataset Loaded and Preprocessed Successfully!
# Columns in Dataset: Index(['date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Dividends', 'Stock Splits', 'date_only', 'hour', 'day_of_week'],
#       dtype='object')
# Data Types:
# date            datetime64[ns]
# Open                   float64
# High                   float64
# Low                    float64
# Close                  float64
# Adj Close              float64
# Volume                   int64
# Dividends              float64
# Stock Splits           float64
# date_only               object
# hour                     int32
# day_of_week             object
# dtype: object
#
# First few rows of data from NVDA_historical_data.csv:
#         date      Open      High       Low     Close  Adj Close      Volume  \
# 0 1999-01-22  0.043750  0.048828  0.038802  0.041016   0.037621  2714688000
# 1 1999-01-25  0.044271  0.045833  0.041016  0.045313   0.041562   510480000
# 2 1999-01-26  0.045833  0.046745  0.041146  0.041797   0.038337   343200000
# 3 1999-01-27  0.041927  0.042969  0.039583  0.041667   0.038218   244368000
# 4 1999-01-28  0.041667  0.041927  0.041276  0.041536   0.038098   227520000
#
#    Dividends  Stock Splits   date_only  hour day_of_week
# 0        0.0           0.0  1999-01-22     0      Friday
# 1        0.0           0.0  1999-01-25     0      Monday
# 2        0.0           0.0  1999-01-26     0     Tuesday
# 3        0.0           0.0  1999-01-27     0   Wednesday
# 4        0.0           0.0  1999-01-28     0    Thursday
# Checking file path: D:\Kifya_training\Week 1\Technical  Content\Data\yfinance_data\TSLA_historical_data.csv
# Dataset Loaded and Preprocessed Successfully!
# Columns in Dataset: Index(['date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Dividends', 'Stock Splits', 'date_only', 'hour', 'day_of_week'],
#       dtype='object')
# Data Types:
# date            datetime64[ns]
# Open                   float64
# High                   float64
# Low                    float64
# Close                  float64
# Adj Close              float64
# Volume                   int64
# Dividends              float64
# Stock Splits           float64
# date_only               object
# hour                     int32
# day_of_week             object
# dtype: object
#
# First few rows of data from TSLA_historical_data.csv:
#         date      Open      High       Low     Close  Adj Close     Volume  \
# 0 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 1 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 3 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 4 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
#
#    Dividends  Stock Splits   date_only  hour day_of_week
# 0        0.0           0.0  2010-06-29     0     Tuesday
# 1        0.0           0.0  2010-06-30     0   Wednesday
# 2        0.0           0.0  2010-07-01     0    Thursday
# 3        0.0           0.0  2010-07-02     0      Friday
# 4        0.0           0.0  2010-07-06     0     Tuesday
#         date      Open      High       Low     Close  Adj Close     Volume  \
# 0 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 1 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 3 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 4 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
#
#    Dividends  Stock Splits   date_only  hour day_of_week
# 0        0.0           0.0  2010-06-29     0     Tuesday
# 1        0.0           0.0  2010-06-30     0   Wednesday
# 2        0.0           0.0  2010-07-01     0    Thursday
# 3        0.0           0.0  2010-07-02     0      Friday
# 4        0.0           0.0  2010-07-06     0     Tuesday
